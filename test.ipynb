# %%
import src.activation_functions as activation_functions
import src.initializers as initializers
import src.loss_functions as loss_functions
import src.FFNN as FFNN


activation_function = activation_functions.ReLU()  # Example activation function
initializer = initializers.HeInitializer(a=1)  # Example initializer
loss_function = loss_functions.MSELoss()  # Example loss function
